# %%
import numpy as np

# %%
N_piping = 1 + (0.4 * 42430 / 300)
N_overtop = 3.0
N_slope = 1 + (0.033 * 42430 / 50)
N = [N_overtop, N_slope, N_piping]
omega = [0.24, 0.04, 0.24]
P_req = 1/3000

P_reqi = []
for i in range(len(N)):
    P_reqi.append(round(omega[i] * P_req / N[i], 9))

print(P_reqi)
# Out:
# [2.6667e-05, 4.6e-07, 1.39e-06]
