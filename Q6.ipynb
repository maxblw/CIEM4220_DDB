# %%
import numpy as np

# %%
import numpy as np

def calculate_Rc(q, Hm0, tan_alpha, gamma_b, gamma_f, gamma_beta, gamma_v):
    g = 9.81  # gravity (m/s²)
    RC = []

    for i in range(len(tan_alpha)):
        xi = tan_alpha[i] / np.sqrt(Hm0 / Lm)
    # Calculate the argument inside the logarithm

        numerator = q * np.sqrt(tan_alpha[i])
        denominator = 0.026 * gamma_b * xi * np.sqrt(g * Hm0**3)
        log_argument = numerator / denominator
        print(log_argument)
    
        if log_argument <= 0:
            raise ValueError("Logarithm argument must be positive.")
    
    # Compute the exponential expression
        else: 
            power_term = (-np.log(log_argument))**(1/1.3)
    
    # Final Rc computation
            Rcc = (xi * Hm0 * gamma_b * gamma_f * gamma_beta * gamma_v / 2.5) * power_term
            print(Rcc)
            

        # RC = ((xi * Hm0 * gamma_b * gamma_f * gamma_beta * gamma_v) / 2.5) * ((-np.log(q*np.sqrt(tan_alpha)/(0.026*gamma_b*xi*np.sqrt(g*(Hm0**3)))))**(1/1.3))
        RC.append(Rcc)
    return RC

# %%
# Gegeven:
g = 9.81
Hm0 = 1.2 # m
gamma_f = 0.95
gamma_v = 1
q_lim = 10/1000 # m3/s/m
T = 7 # s
Lm = g * T ** 2 / (2*np.pi)
gamma_beta = 1
print(Lm)
# Out:
# 76.50418959484317

# %%
#Combination A

tan_a_list = np.linspace(0.1, 0.303, 50)
gamma_bA = 1 

A = calculate_Rc(q_lim, Hm0, tan_a_list, gamma_bA, gamma_f, gamma_beta, gamma_v)
print(A)
# Out:
# 0.03699715190829059
# 0.9115094723821672
# 0.03625380117296876
# 0.9537641884871493
# 0.03555352860792293
# 0.9961878631077963
# 0.03489232802025287
# 1.0387738432484468
# 0.03426669613315313
# 1.081515974280647
# 0.03367355422106205
# 1.124408546179483
# 0.033110184170405316
# 1.1674462472104215
# 0.032574175929121235
# 1.2106241238206432
# 0.03206338402269301
# 1.253937545730656
# 0.031575891344198595
# 1.2973821754107586
# 0.031109978822736323
# 1.3409539412756042
# 0.03066409987471006
# 1.3846490140480896
# 0.030236858771473307
# 1.4284637858381424
# 0.02982699223305846
# 1.472394851557926
# 0.02943335369439659
# 1.5164389923565402
# 0.029054899797227876
# 1.5605931608074832
# 0.028690678744934035
# 1.6048544676232823
# 0.0283398202240817
# 1.6492201697056696
# 0.028001526649513764
# 1.693687659367777
# 0.027675065532357757
# 1.7382544545882759
# 0.02735976280461292
# 1.782918190176988
# 0.02705499696177536
# 1.8276766097479689
# 0.02676019390760816
